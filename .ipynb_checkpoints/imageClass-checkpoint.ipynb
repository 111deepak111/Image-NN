# %%
import tensorflow as tf
import PIL
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pathlib

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir=keras.utils.get_file('flower_photos.tar',origin=dataset_url,extract=True)
data_dir=pathlib.Path(data_dir).with_suffix("")

# %%
img_height = 180
img_width = 180

# %%
train_ds=keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.3,
    subset='training',
    seed=123,
    image_size=(img_height,img_width),
)
val_ds=keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.3,
    subset='validation',
    seed=123,
    image_size=(img_height,img_width),
)
class_names=train_ds.class_names
print(class_names)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2569 files for training.
# Found 3670 files belonging to 5 classes.
# Using 1101 files for validation.
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
for image_batch,label_batch in train_ds:
    print(image_batch.shape)
    print(label_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE=tf.data.AUTOTUNE
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds=val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes=len(class_names)
model=Sequential([
    layers.Rescaling(1./255,input_shape=(img_height,img_width,3)),
    layers.Conv2D(16,3,padding='same',activation=layers.LeakyReLU(alpha=0.1)),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3,padding='same',activation=layers.LeakyReLU(alpha=0.1)),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,padding='same',activation=layers.LeakyReLU(alpha=0.1)),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='tanh'),
    layers.Dense(num_classes)
])
model.compile(
    optimizer='adam',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=14
history=model.fit(train_ds,validation_data=val_ds,epochs=epochs,batch_size=213)
# Out:
# Epoch 1/14
# 81/81 [==============================] - 3s 38ms/step - loss: 4.2201e-04 - accuracy: 1.0000 - val_loss: 1.8499 - val_accuracy: 0.6412
# Epoch 2/14
# 81/81 [==============================] - 3s 38ms/step - loss: 3.7983e-04 - accuracy: 1.0000 - val_loss: 1.8633 - val_accuracy: 0.6440
# Epoch 3/14
# 81/81 [==============================] - 3s 38ms/step - loss: 3.4439e-04 - accuracy: 1.0000 - val_loss: 1.8800 - val_accuracy: 0.6467
# Epoch 4/14
# 81/81 [==============================] - 3s 39ms/step - loss: 3.1469e-04 - accuracy: 1.0000 - val_loss: 1.8925 - val_accuracy: 0.6431
# Epoch 5/14
# 81/81 [==============================] - 3s 38ms/step - loss: 2.8587e-04 - accuracy: 1.0000 - val_loss: 1.9062 - val_accuracy: 0.6421
# Epoch 6/14
# 81/81 [==============================] - 3s 38ms/step - loss: 2.6342e-04 - accuracy: 1.0000 - val_loss: 1.9155 - val_accuracy: 0.6412
# Epoch 7/14
# 81/81 [==============================] - 3s 39ms/step - loss: 2.4128e-04 - accuracy: 1.0000 - val_loss: 1.9307 - val_accuracy: 0.6431
# Epoch 8/14
# 81/81 [==============================] - 3s 39ms/step - loss: 2.2349e-04 - accuracy: 1.0000 - val_loss: 1.9475 - val_accuracy: 0.6421
# Epoch 9/14
# 81/81 [==============================] - 3s 38ms/step - loss: 2.0724e-04 - accuracy: 1.0000 - val_loss: 1.9555 - val_accuracy: 0.6421
# Epoch 10/14
# 81/81 [==============================] - 3s 38ms/step - loss: 1.9184e-04 - accuracy: 1.0000 - val_loss: 1.9622 - val_accuracy: 0.6394
# Epoch 11/14
# 81/81 [==============================] - 3s 38ms/step - loss: 1.7819e-04 - accuracy: 1.0000 - val_loss: 1.9741 - val_accuracy: 0.6421
# Epoch 12/14
# 81/81 [==============================] - 3s 38ms/step - loss: 1.6704e-04 - accuracy: 1.0000 - val_loss: 1.9873 - val_accuracy: 0.6440
# Epoch 13/14
# 81/81 [==============================] - 3s 38ms/step - loss: 1.5498e-04 - accuracy: 1.0000 - val_loss: 1.9927 - val_accuracy: 0.6394
# Epoch 14/14
# 81/81 [==============================] - 3s 39ms/step - loss: 1.4509e-04 - accuracy: 1.0000 - val_loss: 2.0074 - val_accuracy: 0.6421

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation=keras.Sequential([
    layers.RandomFlip('horizontal',input_shape=(img_height,img_width,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
model=Sequential([
    data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  outputs (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=20
history=model.fit(
    train_ds,validation_data=val_ds,epochs=epochs,batch_size=512
)
# Out:
# Epoch 1/20
# 81/81 [==============================] - 25s 307ms/step - loss: 0.9134 - accuracy: 0.6450 - val_loss: 1.0141 - val_accuracy: 0.5985
# Epoch 2/20
# 81/81 [==============================] - 25s 305ms/step - loss: 0.8485 - accuracy: 0.6742 - val_loss: 0.8916 - val_accuracy: 0.6658
# Epoch 3/20
# 81/81 [==============================] - 24s 303ms/step - loss: 0.7926 - accuracy: 0.6944 - val_loss: 0.9324 - val_accuracy: 0.6431
# Epoch 4/20
# 81/81 [==============================] - 25s 314ms/step - loss: 0.7617 - accuracy: 0.7123 - val_loss: 0.8450 - val_accuracy: 0.6721
# Epoch 5/20
# 81/81 [==============================] - 25s 305ms/step - loss: 0.7502 - accuracy: 0.7139 - val_loss: 0.8093 - val_accuracy: 0.6957
# Epoch 6/20
# 81/81 [==============================] - 24s 301ms/step - loss: 0.6653 - accuracy: 0.7532 - val_loss: 0.8274 - val_accuracy: 0.6812
# Epoch 7/20
# 81/81 [==============================] - 24s 301ms/step - loss: 0.6561 - accuracy: 0.7454 - val_loss: 0.7913 - val_accuracy: 0.6939
# Epoch 8/20
# 81/81 [==============================] - 26s 317ms/step - loss: 0.6036 - accuracy: 0.7692 - val_loss: 0.8355 - val_accuracy: 0.6830
# Epoch 9/20
# 81/81 [==============================] - 27s 335ms/step - loss: 0.5870 - accuracy: 0.7797 - val_loss: 0.8017 - val_accuracy: 0.6903
# Epoch 10/20
# 81/81 [==============================] - 25s 314ms/step - loss: 0.5310 - accuracy: 0.8046 - val_loss: 0.8366 - val_accuracy: 0.7094
# Epoch 11/20
# 81/81 [==============================] - 24s 291ms/step - loss: 0.5323 - accuracy: 0.8023 - val_loss: 0.9170 - val_accuracy: 0.6857
# Epoch 12/20
# 81/81 [==============================] - 23s 287ms/step - loss: 0.4927 - accuracy: 0.8139 - val_loss: 0.8003 - val_accuracy: 0.7112
# Epoch 13/20
# 81/81 [==============================] - 24s 302ms/step - loss: 0.4572 - accuracy: 0.8295 - val_loss: 0.9444 - val_accuracy: 0.6912
# Epoch 14/20
# 81/81 [==============================] - 26s 319ms/step - loss: 0.4579 - accuracy: 0.8307 - val_loss: 0.8297 - val_accuracy: 0.7066
# Epoch 15/20
# 81/81 [==============================] - 27s 336ms/step - loss: 0.3783 - accuracy: 0.8618 - val_loss: 0.8840 - val_accuracy: 0.7039
# Epoch 16/20
# 81/81 [==============================] - 27s 329ms/step - loss: 0.3676 - accuracy: 0.8696 - val_loss: 0.9447 - val_accuracy: 0.7075
# Epoch 17/20
# 81/81 [==============================] - 27s 330ms/step - loss: 0.3485 - accuracy: 0.8735 - val_loss: 0.9076 - val_accuracy: 0.7066
# Epoch 18/20
# 81/81 [==============================] - 27s 332ms/step - loss: 0.3300 - accuracy: 0.8774 - val_loss: 0.8808 - val_accuracy: 0.7230
# Epoch 19/20
# 81/81 [==============================] - 27s 329ms/step - loss: 0.3091 - accuracy: 0.8832 - val_loss: 0.9694 - val_accuracy: 0.7003
# Epoch 20/20
# 81/81 [==============================] - 26s 324ms/step - loss: 0.2921 - accuracy: 0.8914 - val_loss: 0.9209 - val_accuracy: 0.7212

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
model.save('Flowers.keras')

# %%
sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

img = tf.keras.utils.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 1s 534ms/step
# This image most likely belongs to sunflowers with a 99.99 percent confidence.

# %%
model = tf.keras.models.load_model('Flowers.keras')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
data_dir=".\flower_photos\flower_photos"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data_dir=keras.utils.get_file('flower_photos.tgz',extract=True)
#       2 data_dir=pathlib.Path(data_dir).with_suffix("")
#
# File C:\ProgramData\miniconda3\envs\tf\lib\site-packages\keras\utils\data_utils.py:217, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     167 """Downloads a file from a URL if it not already in the cache.
#     168
#     169 By default the file at the url `origin` is downloaded to the
#    (...)
#     214     Path to the downloaded file
#     215 """
#     216 if origin is None:
# --> 217     raise ValueError(
#     218         'Please specify the "origin" argument (URL of the file '
#     219         "to download)."
#     220     )
#     222 if cache_dir is None:
#     223     cache_dir = os.path.join(os.path.expanduser("~"), ".keras")
#
# ValueError: Please specify the "origin" argument (URL of the file to download).

# %%
train_ds=keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.3,
    subset='training',
    seed=123,
    image_size=(img_height,img_width),
)
val_ds=keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.3,
    subset='validation',
    seed=123,
    image_size=(img_height,img_width),
)
